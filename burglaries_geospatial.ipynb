# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from jupyterthemes import jtplot
import requests
import json
jtplot.style()

# %% [markdown]
# # Problem 1: Burglaries
#
# A dataset containing details about Metro Nashville Police Department reported incidents is available at https://data.nashville.gov/Police/Metro-Nashville-Police-Department-Incidents/2u6v-ujjs. Make use of the API to find all aggravated burglary incidents that were reported during the six month period from January 1, 2021 through June 30, 2021.

# %%
endpoint = "https://data.nashville.gov/resource/2u6v-ujjs.geojson?"
offset = 0
limit = 10000
burg = gpd.GeoDataFrame()
while True:
    params1 = {
        "offense_description":"BURGLARY- AGGRAVATED",
        #offense_nibrs":220,
        "$where":"incident_reported between '2021-01-01T00:00:00.000' and '2021-06-30T00:00:00.000'",
        "$offset":offset,
        "$limit":limit
    }
    res = requests.get(endpoint, params1)
    res_gdf = gpd.read_file(res.text)
    burg = gpd.GeoDataFrame(pd.concat([burg, res_gdf], ignore_index = True))
    
    if len(res_gdf) != limit:
        break
        
    offset += limit

burg = burg.drop_duplicates(subset = 'incident_number')
burg
# Out:
#      victim_county_resident zip_code victim_number offense_nibrs   rpa  \
# 0                  RESIDENT     None             1           220  8203
# 1                  RESIDENT     None             1           220  9615
# 2              NON RESIDENT     None             1           220  6901
# 3              NON RESIDENT     None             3           220  None
# 5                  RESIDENT     None             2           220  8401
# ...                     ...      ...           ...           ...   ...
# 1041               RESIDENT    37013             1           220  8861
# 1042               RESIDENT    37210             1           220  8201
# 1043               RESIDENT    37207             1           220  3013
# 1044                   None     None             1           220  8655
# 1045               RESIDENT     None             1           220  1701
#
#      latitude victim_race incident_number investigation_status offense_number  \
# 0       36.15           B     20210249540                 Open              1
# 1        36.2           W     20210248840                 Open              1
# 2       36.14           W     20210244919                 Open              1
# 3       36.14           W     20210244892                 Open              1
# 5       36.11           W     20210248402                 Open              1
# ...       ...         ...             ...                  ...            ...
# 1041   36.052           B     20210029313               Closed              1
# 1042   36.152           B     20210073787               Closed              1
# 1043   36.204           B     20210127915               Closed              1
# 1044    36.05        None     20210126551                 Open              1
# 1045    36.27           B     20210257587                 Open              1
#
#       ... weapon_primary report_type_description  victim_type  \
# 0     ...             09              DISPATCHED            I
# 1     ...             09              DISPATCHED            I
# 2     ...             17              DISPATCHED            I
# 3     ...             17              DISPATCHED            I
# 5     ...             17              DISPATCHED            I
# ...   ...            ...                     ...          ...
# 1041  ...             01              DISPATCHED            I
# 1042  ...             09              DISPATCHED            I
# 1043  ...             17              DISPATCHED            I
# 1044  ...             17                    None            B
# 1045  ...             16              DISPATCHED            I
#
#      incident_status_code incident_status_description  zone victim_gender  \
# 0                       O                        OPEN   511             F
# 1                       O                        OPEN   525             F
# 2                       O                        OPEN   815             M
# 3                       O                        OPEN  None             M
# 5                       O                        OPEN   313             F
# ...                   ...                         ...   ...           ...
# 1041                    A           CLEARED BY ARREST   327             F
# 1042                    A           CLEARED BY ARREST   511             F
# 1043                    A           CLEARED BY ARREST   631             M
# 1044                    O                        OPEN   827          None
# 1045                    O                        OPEN   715             M
#
#         incident_occurred     primary_key                    geometry
# 0     2021-05-04T23:45:00  20210249540_11  POINT (-86.77000 36.15000)
# 1     2021-05-04T12:06:00  20210248840_11  POINT (-86.63000 36.20000)
# 2     2021-05-01T23:00:00  20210244919_11  POINT (-86.78000 36.14000)
# 3     2021-05-01T21:30:00  20210244892_13  POINT (-86.78000 36.14000)
# 5     2021-05-04T00:00:00  20210248402_12  POINT (-86.73000 36.11000)
# ...                   ...             ...                         ...
# 1041  2021-01-15T21:50:00  20210029313_11  POINT (-86.64700 36.05200)
# 1042  2021-02-06T12:00:00  20210073787_11  POINT (-86.76500 36.15200)
# 1043  2021-03-03T15:30:00  20210127915_11  POINT (-86.80700 36.20400)
# 1044  2021-02-23T10:30:00  20210126551_11  POINT (-86.72000 36.05000)
# 1045  2021-05-07T16:30:00  20210257587_11  POINT (-86.71000 36.27000)
#
# [824 rows x 31 columns]

# %% [markdown]
# # Problem 2: Census Tract Shapefiles
#
# Download the 2019 census tract shapefiles for Tennessee from https://www.census.gov/geographies/mapping-files/time-series/geo/tiger-line-file.2019.html. (The FIPS code for Tennessee is 47). Perform a spatial join to determine the census tract in which each burglary incident occurred. Which census tract had the highest number of burglaries? Warning - each incident can appear multiple times if there are multiple victims, so be sure that you aren't double-counting any incidents.

# %%
tn_tracts = gpd.read_file("data/tl_2019_47_tract.shp").to_crs(epsg = 4326)

# %%
tn_tracts.columns = tn_tracts.columns.str.lower()

# %%
tn_tracts = (tn_tracts.rename(columns = {'statefp':'state',
                            'countyfp':'county',
                            'tractce':'tract'}
                )
                .drop(columns = ['name', 'namelsad'])
            )

# %%
tn_bur = gpd.sjoin(burg, tn_tracts, op = 'within')

# %%
tn_bur.value_counts('tract')
# Out:
# tract
# 016300    53
# 016200    21
# 011001    20
# 019500    19
# 019300    19
#           ..
# 011900     1
# 018700     1
# 015405     1
# 018601     1
# 015627     1
# Length: 147, dtype: int64

# %% [markdown]
# # Problem 3: Populations
#
# For this part, you'll need to request a census API key. Using the 2019 American Community Survey API, obtain, for each census tract, the population (B01001_001E in the detailed tables) and the median income (S1901_C01_012E in the subject tables). Hint: Tennessee's FIPS code is 47 and Davidson County's FIPS code is 37. Merge this new data with the burglaries data above.

# %%
with open('C:/Users/jrior/Documents/NSS/api_keys.json') as fi:
    credentials = json.load(fi)
    
api_key = credentials['census_data']

# %%
endpoint = "https://api.census.gov/data/2019/acs/acs5?"
query = f"get=NAME,B01001_001E&for=tract:*&in=state:47"#&key={api_key}"
response2 = requests.get(endpoint+query)
response2
# Out:
# <Response [200]>

# %%
res2_dict = response2.json()
tn_pops = pd.DataFrame().from_dict(res2_dict)
tn_pops.columns = tn_pops.loc[0]
tn_pops = (tn_pops.drop(tn_pops.index[0])
           .reset_index(drop = True)
           .rename(columns = {'NAME': 'name',
                              'B01001_001E': 'population'}
                  )
          )

# %%
endpoint = "https://api.census.gov/data/2019/acs/acs5/subject?"
query = f"get=NAME,S1901_C01_012E&for=tract:*&in=state:47"#&key={api_key}"
response3 = requests.get(endpoint+query)
response3
# Out:
# <Response [200]>

# %%
res3_dict = response3.json()
tn_med_inc = pd.DataFrame().from_dict(res3_dict)
tn_med_inc.columns = tn_med_inc.loc[0]
tn_med_inc = (tn_med_inc.drop(tn_med_inc.index[0])
              .reset_index(drop = True)
              .rename(columns = {'NAME': 'name',
                                 'S1901_C01_012E': 'median_income'}
                     )
             )

# %%
tn = tn_pops.merge(tn_med_inc)
tn[['county_name', 'state_name']] = (tn['name'].str.split(pat = ', ',
                             expand = True
                            )
               .drop(columns = [0])
    )
tn = tn.drop(columns = 'name')

# %%
tn_burgs = tn.merge(tn_bur)

# %%
tn_burgs[tn_burgs['tract'] == '016300']
# Out:
#     population state county   tract median_income      county_name state_name  \
# 356       2560    47    037  016300         50710  Davidson County  Tennessee
# 357       2560    47    037  016300         50710  Davidson County  Tennessee
# 358       2560    47    037  016300         50710  Davidson County  Tennessee
# 359       2560    47    037  016300         50710  Davidson County  Tennessee
# 360       2560    47    037  016300         50710  Davidson County  Tennessee
# 361       2560    47    037  016300         50710  Davidson County  Tennessee
# 362       2560    47    037  016300         50710  Davidson County  Tennessee
# 363       2560    47    037  016300         50710  Davidson County  Tennessee
# 364       2560    47    037  016300         50710  Davidson County  Tennessee
# 365       2560    47    037  016300         50710  Davidson County  Tennessee
# 366       2560    47    037  016300         50710  Davidson County  Tennessee
# 367       2560    47    037  016300         50710  Davidson County  Tennessee
# 368       2560    47    037  016300         50710  Davidson County  Tennessee
# 369       2560    47    037  016300         50710  Davidson County  Tennessee
# 370       2560    47    037  016300         50710  Davidson County  Tennessee
# 371       2560    47    037  016300         50710  Davidson County  Tennessee
# 372       2560    47    037  016300         50710  Davidson County  Tennessee
# 373       2560    47    037  016300         50710  Davidson County  Tennessee
# 374       2560    47    037  016300         50710  Davidson County  Tennessee
# 375       2560    47    037  016300         50710  Davidson County  Tennessee
# 376       2560    47    037  016300         50710  Davidson County  Tennessee
# 377       2560    47    037  016300         50710  Davidson County  Tennessee
# 378       2560    47    037  016300         50710  Davidson County  Tennessee
# 379       2560    47    037  016300         50710  Davidson County  Tennessee
# 380       2560    47    037  016300         50710  Davidson County  Tennessee
# 381       2560    47    037  016300         50710  Davidson County  Tennessee
# 382       2560    47    037  016300         50710  Davidson County  Tennessee
# 383       2560    47    037  016300         50710  Davidson County  Tennessee
# 384       2560    47    037  016300         50710  Davidson County  Tennessee
# 385       2560    47    037  016300         50710  Davidson County  Tennessee
# 386       2560    47    037  016300         50710  Davidson County  Tennessee
# 387       2560    47    037  016300         50710  Davidson County  Tennessee
# 388       2560    47    037  016300         50710  Davidson County  Tennessee
# 389       2560    47    037  016300         50710  Davidson County  Tennessee
# 390       2560    47    037  016300         50710  Davidson County  Tennessee
# 391       2560    47    037  016300         50710  Davidson County  Tennessee
# 392       2560    47    037  016300         50710  Davidson County  Tennessee
# 393       2560    47    037  016300         50710  Davidson County  Tennessee
# 394       2560    47    037  016300         50710  Davidson County  Tennessee
# 395       2560    47    037  016300         50710  Davidson County  Tennessee
# 396       2560    47    037  016300         50710  Davidson County  Tennessee
# 397       2560    47    037  016300         50710  Davidson County  Tennessee
# 398       2560    47    037  016300         50710  Davidson County  Tennessee
# 399       2560    47    037  016300         50710  Davidson County  Tennessee
# 400       2560    47    037  016300         50710  Davidson County  Tennessee
# 401       2560    47    037  016300         50710  Davidson County  Tennessee
# 402       2560    47    037  016300         50710  Davidson County  Tennessee
# 403       2560    47    037  016300         50710  Davidson County  Tennessee
# 404       2560    47    037  016300         50710  Davidson County  Tennessee
# 405       2560    47    037  016300         50710  Davidson County  Tennessee
# 406       2560    47    037  016300         50710  Davidson County  Tennessee
# 407       2560    47    037  016300         50710  Davidson County  Tennessee
# 408       2560    47    037  016300         50710  Davidson County  Tennessee
#
#     victim_county_resident zip_code victim_number  ...     primary_key  \
# 356           NON RESIDENT     None             6  ...  20210240530_16
# 357           NON RESIDENT     None             3  ...  20210232671_13
# 358               RESIDENT     None             5  ...  20210203105_25
# 359               RESIDENT     None             1  ...  20210035296_11
# 360           NON RESIDENT     None             1  ...  20210212785_11
# 361           NON RESIDENT     None             1  ...  20210183062_11
# 362               RESIDENT     None             1  ...  20210065567_11
# 363               RESIDENT     None             1  ...  20210146767_11
# 364           NON RESIDENT     None             1  ...  20210187464_11
# 365               RESIDENT     None             1  ...  20210160726_11
# 366               RESIDENT     None             1  ...  20210173930_11
# 367               RESIDENT     None             1  ...  20210054644_11
# 368               RESIDENT     None             1  ...  20210144984_11
# 369               RESIDENT     None             1  ...  20210179166_11
# 370               RESIDENT     None             1  ...  20210237604_11
# 371           NON RESIDENT     None             1  ...  20210205918_11
# 372           NON RESIDENT     None             2  ...  20210184942_12
# 373           NON RESIDENT     None             1  ...  20210185459_11
# 374               RESIDENT     None             1  ...  20210224205_11
# 375               RESIDENT     None             1  ...  20210212551_21
# 376           NON RESIDENT     None             2  ...  20210271293_12
# 377               RESIDENT     None             1  ...  20210260790_21
# 378               RESIDENT     None             1  ...  20210270194_11
# 379           NON RESIDENT     None             1  ...  20210271039_11
# 380           NON RESIDENT     None             1  ...  20210276324_21
# 381               RESIDENT     None             1  ...  20210270096_11
# 382           NON RESIDENT     None             1  ...  20210280886_11
# 383           NON RESIDENT     None             3  ...  20210284725_13
# 384           NON RESIDENT     None             1  ...  20210286033_11
# 385           NON RESIDENT     None             1  ...  20210281080_21
# 386           NON RESIDENT     None             1  ...  20210298370_11
# 387           NON RESIDENT     None             3  ...  20210299272_13
# 388           NON RESIDENT     None             1  ...  20210300857_11
# 389               RESIDENT     None             1  ...  20210310936_11
# 390               RESIDENT    37212             1  ...  20210257295_21
# 391               RESIDENT     None             1  ...  20210316128_11
# 392           NON RESIDENT     None             5  ...  20210320195_15
# 393           NON RESIDENT     None             3  ...  20210323659_13
# 394           NON RESIDENT     None             1  ...  20210322461_11
# 395           NON RESIDENT     None             1  ...  20210326062_11
# 396           NON RESIDENT     None             3  ...  20210309038_13
# 397           NON RESIDENT     None             1  ...  20210323605_11
# 398               RESIDENT     None             1  ...  20210317589_11
# 399                UNKNOWN     None             1  ...  20210337317_21
# 400           NON RESIDENT     None             3  ...  20210333120_13
# 401           NON RESIDENT     None             1  ...  20210324875_11
# 402               RESIDENT     None             1  ...  20210292985_21
# 403               RESIDENT    37212             1  ...  20210215875_11
# 404               RESIDENT     None             1  ...  20210210606_11
# 405               RESIDENT    37212             1  ...  20210215724_11
# 406           NON RESIDENT     None             2  ...  20210258230_12
# 407           NON RESIDENT     None             2  ...  20210244989_12
# 408                   None     None             1  ...  20210073615_11
#
#                        geometry index_right        geoid  mtfcc funcstat  \
# 356  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 357  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 358  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 359  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 360  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 361  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 362  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 363  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 364  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 365  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 366  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 367  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 368  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 369  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 370  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 371  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 372  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 373  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 374  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 375  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 376  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 377  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 378  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 379  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 380  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 381  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 382  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 383  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 384  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 385  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 386  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 387  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 388  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 389  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 390  POINT (-86.78800 36.14000)         677  47037016300  G5020        S
# 391  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 392  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 393  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 394  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 395  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 396  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 397  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 398  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 399  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 400  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 401  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 402  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
# 403  POINT (-86.78800 36.14000)         677  47037016300  G5020        S
# 404  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 405  POINT (-86.78800 36.14000)         677  47037016300  G5020        S
# 406  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 407  POINT (-86.79000 36.14000)         677  47037016300  G5020        S
# 408  POINT (-86.79000 36.15000)         677  47037016300  G5020        S
#
#        aland awater     intptlat      intptlon
# 356  1099214      0  +36.1431906  -086.7899132
# 357  1099214      0  +36.1431906  -086.7899132
# 358  1099214      0  +36.1431906  -086.7899132
# 359  1099214      0  +36.1431906  -086.7899132
# 360  1099214      0  +36.1431906  -086.7899132
# 361  1099214      0  +36.1431906  -086.7899132
# 362  1099214      0  +36.1431906  -086.7899132
# 363  1099214      0  +36.1431906  -086.7899132
# 364  1099214      0  +36.1431906  -086.7899132
# 365  1099214      0  +36.1431906  -086.7899132
# 366  1099214      0  +36.1431906  -086.7899132
# 367  1099214      0  +36.1431906  -086.7899132
# 368  1099214      0  +36.1431906  -086.7899132
# 369  1099214      0  +36.1431906  -086.7899132
# 370  1099214      0  +36.1431906  -086.7899132
# 371  1099214      0  +36.1431906  -086.7899132
# 372  1099214      0  +36.1431906  -086.7899132
# 373  1099214      0  +36.1431906  -086.7899132
# 374  1099214      0  +36.1431906  -086.7899132
# 375  1099214      0  +36.1431906  -086.7899132
# 376  1099214      0  +36.1431906  -086.7899132
# 377  1099214      0  +36.1431906  -086.7899132
# 378  1099214      0  +36.1431906  -086.7899132
# 379  1099214      0  +36.1431906  -086.7899132
# 380  1099214      0  +36.1431906  -086.7899132
# 381  1099214      0  +36.1431906  -086.7899132
# 382  1099214      0  +36.1431906  -086.7899132
# 383  1099214      0  +36.1431906  -086.7899132
# 384  1099214      0  +36.1431906  -086.7899132
# 385  1099214      0  +36.1431906  -086.7899132
# 386  1099214      0  +36.1431906  -086.7899132
# 387  1099214      0  +36.1431906  -086.7899132
# 388  1099214      0  +36.1431906  -086.7899132
# 389  1099214      0  +36.1431906  -086.7899132
# 390  1099214      0  +36.1431906  -086.7899132
# 391  1099214      0  +36.1431906  -086.7899132
# 392  1099214      0  +36.1431906  -086.7899132
# 393  1099214      0  +36.1431906  -086.7899132
# 394  1099214      0  +36.1431906  -086.7899132
# 395  1099214      0  +36.1431906  -086.7899132
# 396  1099214      0  +36.1431906  -086.7899132
# 397  1099214      0  +36.1431906  -086.7899132
# 398  1099214      0  +36.1431906  -086.7899132
# 399  1099214      0  +36.1431906  -086.7899132
# 400  1099214      0  +36.1431906  -086.7899132
# 401  1099214      0  +36.1431906  -086.7899132
# 402  1099214      0  +36.1431906  -086.7899132
# 403  1099214      0  +36.1431906  -086.7899132
# 404  1099214      0  +36.1431906  -086.7899132
# 405  1099214      0  +36.1431906  -086.7899132
# 406  1099214      0  +36.1431906  -086.7899132
# 407  1099214      0  +36.1431906  -086.7899132
# 408  1099214      0  +36.1431906  -086.7899132
#
# [53 rows x 46 columns]

# %% [markdown]
# # Problem 4
#
# Create a choropleth showing the number of burglaries per 1000 residents for each census tract.

# %% [markdown]
# # Problem 5
#
# Finally, we'll build some statistical models to see how well we can explain the number of aggravated burglaries using the median income of each census tract. For this, we'll be using the Generalized Linear Models module of the statsmodels library.

# %% [markdown]
# a. Build a "base model" - a Poisson regression model with just an intercept term with target variable the rate of burglaries per census tract. (Offset using the [log of the] population so that we are looking at the rate of burglaries per population instead of the number of burglaries.)

# %% [markdown]
# b. Now, build a Poisson regression model with target variable the rate of burglaries and predictor variable the median income. (Don't forget to offset by the population).

# %% [markdown]
# c. Finally, try out a negative binomial model. To get started with a negative binomial model, you can check out this tutorial.

# %% [markdown]
# d. How do your models compare? Hint: the fit models have an AIC attribute.

# %% [markdown]
# # Problem 6: Presentation
